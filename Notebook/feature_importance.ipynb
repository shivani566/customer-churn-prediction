# %%
import pandas as pd
# Update path to your cleaned churn data CSV
df = pd.read_csv(r'C:\Users\vlogs\OneDrive\Desktop\Churn Prediction\Data\cleaned_churn_data.csv')
# Drop non-feature column
df.drop('customerID', axis=1, inplace=True)

# Map binary columns if needed (e.g., Churn)
df['Churn'] = df['Churn'].map({'Yes': 1, 'No': 0})

# Separate features and target
X = df.drop('Churn', axis=1)
y = df['Churn']

# Convert categorical variables (one-hot encoding)
X = pd.get_dummies(X, drop_first=True)
